# %% [markdown]
# ## Assignment 2: The Shopping List Manager

# %%
'''1. Create a list named shopping_list containing at least 5 initial items (e.g., "milk", "bread", "eggs", "apples", "chicken").
2. Print the entire list, and also print the third item in the list.
3. Add two new items to the list using an appropriate list method.
4. Remove one item from the list.
5. Create a dictionary named item_prices. The keys should be items from your shopping list (at least 4), and the values should be their prices (as floats).
6. Print the price of one specific item from the dictionary.
7. Print a formatted summary of your final shopping list and the price dictionary.
'''
shopping_list = ["milk", "bread", "eggs", "apples", "chicken"] #Create list
print(shopping_list)

print ("the third item in the list is :", shopping_list[2]) #third item

shopping_list.append("cheese") # Add two items
shopping_list.append("coffee")

print("After adding items:", shopping_list)


shopping_list.remove("apples") #Remove one item

print("After removing apples:", shopping_list)

# Create dictionary with prices
item_prices = {
    "milk": 2.5,
    "bread": 1.8,
    "eggs": 3.0,
    "chicken": 7.5
}
print("Price of milk:", item_prices["milk"]) # Print price of one item

print("Final Shopping List:", shopping_list)
print("Item Prices:", item_prices)
# Out:
# ['milk', 'bread', 'eggs', 'apples', 'chicken']
# the third item in the list is : eggs
# After adding items: ['milk', 'bread', 'eggs', 'apples', 'chicken', 'cheese', 'coffee']
# After removing apples: ['milk', 'bread', 'eggs', 'chicken', 'cheese', 'coffee']
# Price of milk: 2.5
# Final Shopping List: ['milk', 'bread', 'eggs', 'chicken', 'cheese', 'coffee']
# Item Prices: {'milk': 2.5, 'bread': 1.8, 'eggs': 3.0, 'chicken': 7.5}
